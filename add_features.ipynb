# %%
import pandas as pd
import os


df_k = pd.read_csv('imdb_5000_movies.csv')
df_k.columns

#grab each movie id from the movie link in kaggle dataset
imdb_ids = [df_k.iloc[i]['movie_imdb_link'].split('title/')[1].split('/?')[0] for i in range(len(df_k))]

#create empty dataframe with relevent columns
df = pd.DataFrame(columns=['Title', 'Year', 'ID', 'Plot', 'Genre', 'Production', 'Director', 'Actor_1_name', 'Actor_1_fb_likes', 'Actor_2_name', 'Actor_2_fb_likes', 'Actor_3_name', 'Actor_3_fb_likes', 'Budget', 'Rated', 'Language', 'imdbRating'])

for i in range(len(imdb_ids)):
    id = df_k.iloc[i]['movie_imdb_link'].split('title/')[1].split('/?')[0]
    x_file = open(os.path.join('Movies', f"movie_{id}"), "r")    #open up the movie's text file
    movie_text = x_file.readlines()[0]
    dict = eval(movie_text)    #turn string back to dictionary
    dict['Plot'] = dict['Plot'].replace("\'", "'")    #clean up
    df = df.append({'Title': dict['Title'], 'Year': dict['Year'], 'ID': id, 'Plot': dict['Plot'], 'Genre': dict['Genre'], 'imdbRating': dict['imdbRating'], 'Director': df_k.iloc[i,:].loc['director_name'], 'Actor_1_name':df_k.iloc[i,:].loc['actor_1_name'], 'Actor_1_fb_likes':df_k.iloc[i,:].loc['actor_1_facebook_likes'], 'Actor_2_name':df_k.iloc[i,:].loc['actor_2_name'], 'Actor_2_fb_likes':df_k.iloc[i,:].loc['actor_2_facebook_likes'], 'Actor_3_name':df_k.iloc[i,:].loc['actor_3_name'], 'Actor_3_fb_likes':df_k.iloc[i,:].loc['actor_3_facebook_likes'], 'Budget':df_k.iloc[i,:].loc['budget'], 'Language':dict['Language'], 'Rated':dict['Rated']}, ignore_index=True)    #add to dataframe

# %%
# Out:
#                                             Title       Year         ID  \
# 0                                          Avatar       2009  tt0499549
# 1        Pirates of the Caribbean: At World's End       2007  tt0449088
# 2                                         Spectre       2015  tt2379713
# 3                           The Dark Knight Rises       2012  tt1345836
# 4      Star Wars: Episode VII - The Force Awakens       2015  tt5289954
# 5                                     John Carter       2012  tt0401729
# 6                                    Spider-Man 3       2007  tt0413300
# 7                                         Tangled       2010  tt0398286
# 8                         Avengers: Age of Ultron       2015  tt2395427
# 9          Harry Potter and the Half-Blood Prince       2009  tt0417741
# 10             Batman v Superman: Dawn of Justice       2016  tt2975590
# 11                               Superman Returns       2006  tt0348150
# 12                              Quantum of Solace       2008  tt0830515
# 13     Pirates of the Caribbean: Dead Man's Chest       2006  tt0383574
# 14                                The Lone Ranger       2013  tt1210819
# 15                                   Man of Steel       2013  tt0770828
# 16       The Chronicles of Narnia: Prince Caspian       2008  tt0499448
# 17                                   The Avengers       2012  tt0848228
# 18    Pirates of the Caribbean: On Stranger Tides       2011  tt1298650
# 19                                 Men in Black 3       2012  tt1409024
# 20      The Hobbit: The Battle of the Five Armies       2014  tt2310332
# 21                         The Amazing Spider-Man       2012  tt0948470
# 22                                     Robin Hood       2010  tt0955308
# 23            The Hobbit: The Desolation of Smaug       2013  tt1170358
# 24                             The Golden Compass       2007  tt0385752
# 25                                      King Kong       2005  tt0360717
# 26                                        Titanic       1997  tt0120338
# 27                     Captain America: Civil War       2016  tt3498820
# 28                                     Battleship       2012  tt1440129
# 29                                 Jurassic World       2015  tt0369610
# ...                                           ...        ...        ...
# 5013                                       Manito       2002  tt0298050
# 5014                                      Rampage       2009  tt1337057
# 5015                                      Slacker       1990  tt0102943
# 5016                                  Dutch Kills       2015  tt2759066
# 5017                                    Dry Spell       2013  tt2375036
# 5018                                     Flywheel       2003  tt0425027
# 5019                                       Exeter       2015  tt1945044
# 5020                                   The Ridges       2011  tt1781935
# 5021                              The Puffy Chair       2005  tt0436689
# 5022                         Stories of Our Lives       2014  tt3973612
# 5023                             Breaking Upwards       2009  tt1247644
# 5024                     All Superheroes Must Die       2011  tt1836212
# 5025                               Pink Flamingos       1972  tt0069089
# 5026                                        Clean       2004  tt0388838
# 5027                                   The Circle       2000  tt0255094
# 5028                                  Tin Can Man       2007  tt1235811
# 5029                                         Cure       1997  tt0123948
# 5030                               On the Downlow       2004  tt0390323
# 5031                 Sanctuary; Quite a Conundrum       2012  tt2049518
# 5032                                         Bang       1995  tt0109266
# 5033                                       Primer       2004  tt0390384
# 5034                                       Cavite       2005  tt0428303
# 5035                                  El Mariachi       1992  tt0104815
# 5036                              The Mongol King       2005  tt0430371
# 5037                                    Newlyweds       2011  tt1880418
# 5038                      Signed Sealed Delivered       2013  tt3000844
# 5039                                The Following  2013–2015  tt2071645
# 5040                         A Plague So Pleasant       2013  tt2107644
# 5041                             Shanghai Calling       2012  tt2070597
# 5042                            My Date with Drew       2004  tt0378407
#
#                                                    Plot  \
# 0     When his brother is killed in a robbery, parap...
# 1     After Elizabeth, Will, and Captain Barbossa re...
# 2     A cryptic message from the past sends James Bo...
# 3     Despite his tarnished reputation after the eve...
# 4                                                   N/A
# 5     John Carter, a Civil War veteran, who in 1868 ...
# 6     Peter Parker has finally managed to piece toge...
# 7     After receiving the healing powers from a magi...
# 8     Tony Stark creates the Ultron Program to prote...
# 9     In the sixth year at Hogwarts School of Witchc...
# 10    The general public is concerned over having Su...
# 11    Following a mysterious absence of several year...
# 12    Is there solace in revenge? Bond and "M" sniff...
# 13    Once again we're plunged into the world of swo...
# 14    In the 1930s, an elderly Tonto tells a young b...
# 15    A young boy learns that he has extraordinary p...
# 16    A year has passed by since the Pevensie childr...
# 17    Nick Fury is the director of S.H.I.E.L.D., an ...
# 18    Captain Jack Sparrow (Depp) crosses paths with...
# 19    After breaking out of a moon-based maximum sec...
# 20    After the Dragon leaves the Lonely Mountain, t...
# 21    Peter Parker (Garfield) is an outcast high sch...
# 22    Birth of a legend. Following King Richard's de...
# 23    After successfully crossing over (and under) t...
# 24    It was no ordinary life for a young girl: livi...
# 25    Carl Denham needs to finish his movie and has ...
# 26    84 years later, a 100 year-old woman named Ros...
# 27    With many people fearing the actions of super ...
# 28    A naval war ship encounters an alien armada an...
# 29    22 years after the original Jurassic Park fail...
# ...                                                 ...
# 5013  Fifteen years ago, their Washington Heights ne...
# 5014  A man with a thirst for revenge builds a full ...
# 5015  Presents a day in the life in Austin, Texas am...
# 5016  A desperate ex-con is forced to gather his old...
# 5017  Sasha tries to get her soon-to-be ex husband K...
# 5018  Jay Austin, a dishonest car salesman in lots o...
# 5019  From the director of Friday the 13th and The T...
# 5020  Four college students at Ohio University set o...
# 5021  Josh and Emily are in a relationship, but he c...
# 5022  A collection of five vignettes about Kenya's L...
# 5023  A young New York couple intricately strategize...
# 5024  Four Super Heroes find themselves abducted by ...
# 5025  Sleaze queen Divine lives in a caravan with he...
# 5026  London-based Emily Wang gained minor notoriety...
# 5027  In a hospital waiting room a woman learns her ...
# 5028  Recently dumped by his girlfriend for another ...
# 5029  A wave of gruesome murders is sweeping Tokyo. ...
# 5030  Isaac and Angel are two young Latinos involved...
# 5031  It should have been just a normal day of sex, ...
# 5032  A young woman in L.A. is having a bad day: she...
# 5033  Engineers Aaron, Abe, Robert and Phillip are w...
# 5034  Flying back to his home country, an American m...
# 5035  El Mariachi just wants to play his guitar and ...
# 5036  Jane McIvory (Sara Stepnicka) has been assigne...
# 5037  Newlyweds Buzzy and Katie find their blissful ...
# 5038  In this prequel to the series, old-fashioned g...
# 5039  The FBI estimates there are currently over 300...
# 5040                A surreal take on the zombie genre.
# 5041  When ambitious New York attorney Sam is sent t...
# 5042  "If you don't take risks, you'll have a wasted...
#
#                                                   Genre  Production  \
# 0                    Action, Adventure, Fantasy, Sci-Fi         NaN
# 1                            Action, Adventure, Fantasy         NaN
# 2                           Action, Adventure, Thriller         NaN
# 3                                      Action, Thriller         NaN
# 4                                           Documentary         NaN
# 5                             Action, Adventure, Sci-Fi         NaN
# 6                             Action, Adventure, Sci-Fi         NaN
# 7     Animation, Adventure, Comedy, Family, Fantasy,...         NaN
# 8                             Action, Adventure, Sci-Fi         NaN
# 9                   Adventure, Family, Fantasy, Mystery         NaN
# 10                   Action, Adventure, Fantasy, Sci-Fi         NaN
# 11                                    Action, Adventure         NaN
# 12                          Action, Adventure, Thriller         NaN
# 13                           Action, Adventure, Fantasy         NaN
# 14                           Action, Adventure, Western         NaN
# 15                   Action, Adventure, Fantasy, Sci-Fi         NaN
# 16                   Action, Adventure, Family, Fantasy         NaN
# 17                            Action, Adventure, Sci-Fi         NaN
# 18                           Action, Adventure, Fantasy         NaN
# 19                    Action, Adventure, Comedy, Sci-Fi         NaN
# 20                                   Adventure, Fantasy         NaN
# 21                            Action, Adventure, Sci-Fi         NaN
# 22           Action, Adventure, Drama, History, Romance         NaN
# 23                                   Adventure, Fantasy         NaN
# 24                           Adventure, Family, Fantasy         NaN
# 25                    Action, Adventure, Drama, Romance         NaN
# 26                                       Drama, Romance         NaN
# 27                            Action, Adventure, Sci-Fi         NaN
# 28                  Action, Adventure, Sci-Fi, Thriller         NaN
# 29                            Action, Adventure, Sci-Fi         NaN
# ...                                                 ...         ...
# 5013                                      Drama, Family         NaN
# 5014                            Action, Crime, Thriller         NaN
# 5015                                      Comedy, Drama         NaN
# 5016                             Crime, Drama, Thriller         NaN
# 5017                                    Comedy, Romance         NaN
# 5018                                              Drama         NaN
# 5019                            Comedy, Horror, Mystery         NaN
# 5020                            Drama, Horror, Thriller         NaN
# 5021                             Comedy, Drama, Romance         NaN
# 5022                                              Drama         NaN
# 5023                                            Romance         NaN
# 5024                                   Sci-Fi, Thriller         NaN
# 5025                                      Comedy, Crime         NaN
# 5026                              Drama, Music, Romance         NaN
# 5027                                              Drama         NaN
# 5028                                             Horror         NaN
# 5029                             Crime, Horror, Mystery         NaN
# 5030                                              Drama         NaN
# 5031                           Comedy, Horror, Thriller         NaN
# 5032                                       Crime, Drama         NaN
# 5033                            Drama, Sci-Fi, Thriller         NaN
# 5034                                           Thriller         NaN
# 5035                            Action, Crime, Thriller         NaN
# 5036                                       Drama, Crime         NaN
# 5037                                      Comedy, Drama         NaN
# 5038                                      Comedy, Drama         NaN
# 5039                    Crime, Drama, Mystery, Thriller         NaN
# 5040                            Drama, Horror, Thriller         NaN
# 5041                             Comedy, Drama, Romance         NaN
# 5042                                        Documentary         NaN
#
#                 Director             Actor_1_name  Actor_1_fb_likes  \
# 0          James Cameron              CCH Pounder            1000.0
# 1         Gore Verbinski              Johnny Depp           40000.0
# 2             Sam Mendes          Christoph Waltz           11000.0
# 3      Christopher Nolan                Tom Hardy           27000.0
# 4            Doug Walker              Doug Walker             131.0
# 5         Andrew Stanton             Daryl Sabara             640.0
# 6              Sam Raimi             J.K. Simmons           24000.0
# 7           Nathan Greno             Brad Garrett             799.0
# 8            Joss Whedon          Chris Hemsworth           26000.0
# 9            David Yates             Alan Rickman           25000.0
# 10           Zack Snyder             Henry Cavill           15000.0
# 11          Bryan Singer             Kevin Spacey           18000.0
# 12          Marc Forster       Giancarlo Giannini             451.0
# 13        Gore Verbinski              Johnny Depp           40000.0
# 14        Gore Verbinski              Johnny Depp           40000.0
# 15           Zack Snyder             Henry Cavill           15000.0
# 16        Andrew Adamson           Peter Dinklage           22000.0
# 17           Joss Whedon          Chris Hemsworth           26000.0
# 18          Rob Marshall              Johnny Depp           40000.0
# 19      Barry Sonnenfeld               Will Smith           10000.0
# 20         Peter Jackson             Aidan Turner            5000.0
# 21             Marc Webb               Emma Stone           15000.0
# 22          Ridley Scott                Mark Addy             891.0
# 23         Peter Jackson             Aidan Turner            5000.0
# 24           Chris Weitz          Christopher Lee           16000.0
# 25         Peter Jackson              Naomi Watts            6000.0
# 26         James Cameron        Leonardo DiCaprio           29000.0
# 27         Anthony Russo        Robert Downey Jr.           21000.0
# 28            Peter Berg              Liam Neeson           14000.0
# 29       Colin Trevorrow      Bryce Dallas Howard            3000.0
# ...                  ...                      ...               ...
# 5013          Eric Eason                 Franky G              93.0
# 5014            Uwe Boll              Matt Frewer             986.0
# 5015   Richard Linklater           Tommy Pallotta               5.0
# 5016     Joseph Mazzella              Tjasa Ferme             313.0
# 5017        Travis Legge           Kristen Seavey             370.0
# 5018       Alex Kendrick           Shannen Fields              51.0
# 5019       Marcus Nispel          Ashley Tramonte             630.0
# 5020     Brandon Landers            Robbie Barnes             720.0
# 5021         Jay Duplass             Mark Duplass             830.0
# 5022          Jim Chuchu               Paul Ogola             147.0
# 5023          Daryl Wein         Zoe Lister-Jones             331.0
# 5024         Jason Trost              Sean Whalen             407.0
# 5025         John Waters                   Divine             462.0
# 5026     Olivier Assayas            Maggie Cheung             576.0
# 5027        Jafar Panahi  Fereshteh Sadre Orafaiy               5.0
# 5028       Ivan Kavanagh        Patrick O'Donnell              10.0
# 5029    Kiyoshi Kurosawa             Kôji Yakusho              89.0
# 5030        Tadeo Garcia      Tatiana Suarez-Pico              21.0
# 5031  Thomas L. Phillips            Julianna Pitt             785.0
# 5032     Ash Baron-Cohen             Peter Greene             789.0
# 5033       Shane Carruth            Shane Carruth             291.0
# 5034    Neill Dela Llana              Ian Gamazon               0.0
# 5035    Robert Rodriguez          Carlos Gallardo             121.0
# 5036     Anthony Vallone           Richard Jewell              45.0
# 5037        Edward Burns              Kerry Bishé             296.0
# 5038         Scott Smith              Eric Mabius             637.0
# 5039                 NaN              Natalie Zea             841.0
# 5040    Benjamin Roberds              Eva Boehnke               0.0
# 5041         Daniel Hsia                Alan Ruck             946.0
# 5042            Jon Gunn              John August              86.0
#
#               Actor_2_name  Actor_2_fb_likes          Actor_3_name  \
# 0         Joel David Moore             936.0             Wes Studi
# 1            Orlando Bloom            5000.0        Jack Davenport
# 2             Rory Kinnear             393.0      Stephanie Sigman
# 3           Christian Bale           23000.0  Joseph Gordon-Levitt
# 4               Rob Walker              12.0                   NaN
# 5          Samantha Morton             632.0          Polly Walker
# 6             James Franco           11000.0         Kirsten Dunst
# 7             Donna Murphy             553.0           M.C. Gainey
# 8        Robert Downey Jr.           21000.0    Scarlett Johansson
# 9         Daniel Radcliffe           11000.0          Rupert Grint
# 10            Lauren Cohan            4000.0        Alan D. Purwin
# 11           Marlon Brando           10000.0        Frank Langella
# 12         Mathieu Amalric             412.0          Rory Kinnear
# 13           Orlando Bloom            5000.0        Jack Davenport
# 14             Ruth Wilson            2000.0         Tom Wilkinson
# 15      Christopher Meloni            3000.0          Harry Lennix
# 16    Pierfrancesco Favino             216.0        Damián Alcázar
# 17       Robert Downey Jr.           21000.0    Scarlett Johansson
# 18             Sam Claflin           11000.0        Stephen Graham
# 19       Michael Stuhlbarg             816.0    Nicole Scherzinger
# 20              Adam Brown             972.0         James Nesbitt
# 21         Andrew Garfield           10000.0           Chris Zylka
# 22            William Hurt             882.0          Scott Grimes
# 23              Adam Brown             972.0         James Nesbitt
# 24               Eva Green            6000.0  Kristin Scott Thomas
# 25      Thomas Kretschmann             919.0            Evan Parke
# 26            Kate Winslet           14000.0         Gloria Stuart
# 27      Scarlett Johansson           19000.0           Chris Evans
# 28     Alexander Skarsgård           10000.0        Tadanobu Asano
# 29              Judy Greer            2000.0               Omar Sy
# ...                    ...               ...                   ...
# 5013        Panchito Gómez              46.0       Casper Martinez
# 5014    Katharine Isabelle             918.0          Michael Paré
# 5015     Richard Linklater               0.0         Jean Caffeine
# 5016          Mikaal Bates              25.0           Damon Owlia
# 5017         Suzi Lorraine             184.0          Travis Legge
# 5018           Lisa Arnold              49.0      Janet Lee Dapper
# 5019       Brittany Curran             512.0     Lindsay MacDonald
# 5020       Alana Kaniewski              19.0       Brandon Landers
# 5021         Katie Aselton             224.0            Bari Hyman
# 5022         Olwenya Maina              19.0        Mugambi Nthiga
# 5023         Heather Burns             212.0    Ebon Moss-Bachrach
# 5024           Jason Trost              91.0         Nick Principe
# 5025            Mink Stole             143.0          Edith Massey
# 5026        Béatrice Dalle             133.0          Don McKellar
# 5027     Nargess Mamizadeh               0.0      Mojgan Faramarzi
# 5028         Michael Parle               5.0      Emma Eliza Regan
# 5029         Anna Nakagawa              13.0                Denden
# 5030        Michael Cortez              20.0           Eric Ambriz
# 5031            Joe Coffey              98.0            John Lucas
# 5032     Stanley B. Herman             194.0           James Noble
# 5033        David Sullivan              45.0          Casey Gooden
# 5034       Edgar Tancangco               0.0             Quynn Ton
# 5035       Peter Marquardt              20.0        Consuelo Gómez
# 5036        John Considine              44.0        Sara Stepnicka
# 5037    Caitlin FitzGerald             205.0       Daniella Pineda
# 5038         Daphne Zuniga             470.0          Crystal Lowe
# 5039         Valorie Curry             593.0         Sam Underwood
# 5040         Maxwell Moody               0.0        David Chandler
# 5041         Daniel Henney             719.0           Eliza Coupe
# 5042      Brian Herzlinger              23.0              Jon Gunn
#
#       Actor_3_fb_likes       Budget      Rated  \
# 0                855.0  237000000.0      PG-13
# 1               1000.0  300000000.0      PG-13
# 2                161.0  245000000.0      PG-13
# 3              23000.0  250000000.0      PG-13
# 4                  NaN          NaN        N/A
# 5                530.0  263700000.0      PG-13
# 6               4000.0  258000000.0      PG-13
# 7                284.0  260000000.0         PG
# 8              19000.0  250000000.0      PG-13
# 9              10000.0  250000000.0         PG
# 10              2000.0  250000000.0      PG-13
# 11               903.0  209000000.0      PG-13
# 12               393.0  200000000.0      PG-13
# 13              1000.0  225000000.0      PG-13
# 14              1000.0  215000000.0      PG-13
# 15               748.0  225000000.0      PG-13
# 16               201.0  225000000.0         PG
# 17             19000.0  220000000.0      PG-13
# 18              1000.0  250000000.0      PG-13
# 19               718.0  225000000.0      PG-13
# 20               773.0  250000000.0      PG-13
# 21               963.0  230000000.0      PG-13
# 22               738.0  200000000.0      PG-13
# 23               773.0  225000000.0      PG-13
# 24              1000.0  180000000.0      PG-13
# 25                84.0  207000000.0      PG-13
# 26               794.0  200000000.0      PG-13
# 27             11000.0  250000000.0      PG-13
# 28               627.0  209000000.0      PG-13
# 29              1000.0  150000000.0      PG-13
# ...                ...          ...        ...
# 5013              42.0      24000.0        N/A
# 5014             492.0          NaN          R
# 5015               0.0      23000.0          R
# 5016               9.0      25000.0      TV-MA
# 5017             138.0      22000.0  NOT RATED
# 5018               4.0      20000.0  NOT RATED
# 5019             265.0          NaN          R
# 5020               8.0      17350.0        N/A
# 5021              10.0      15000.0          R
# 5022               4.0      15000.0        N/A
# 5023             211.0      15000.0        N/A
# 5024              86.0      20000.0    UNRATED
# 5025             105.0      10000.0      NC-17
# 5026              45.0       4500.0          R
# 5027               0.0      10000.0  NOT RATED
# 5028               0.0      10000.0  NOT RATED
# 5029               6.0    1000000.0  NOT RATED
# 5030              12.0          NaN        N/A
# 5031              84.0     200000.0  NOT RATED
# 5032             152.0          NaN        N/A
# 5033               8.0       7000.0      PG-13
# 5034               0.0       7000.0  NOT RATED
# 5035               6.0       7000.0          R
# 5036               2.0       3250.0      PG-13
# 5037             133.0       9000.0  NOT RATED
# 5038             318.0          NaN  NOT RATED
# 5039             319.0          NaN      TV-14
# 5040               0.0       1400.0        N/A
# 5041             489.0          NaN      PG-13
# 5042              16.0       1100.0         PG
#
#                                                Language imdbRating
# 0                                      English, Spanish        7.8
# 1                                               English        7.1
# 2             English, Spanish, Italian, German, French        6.8
# 3                                       English, Arabic        8.4
# 4                                                   N/A        7.2
# 5                                               English        6.6
# 6                                       English, French        6.2
# 7                                               English        7.8
# 8                                       English, Korean        7.4
# 9                                               English        7.6
# 10                                              English        6.5
# 11                              English, German, French        6.1
# 12    English, Spanish, Italian, French, Swiss Germa...        6.6
# 13            English, Turkish, Greek, Mandarin, French        7.3
# 14                       English, North American Indian        6.4
# 15                                              English        7.1
# 16                                              English        6.5
# 17                              English, Russian, Hindi        8.1
# 18                                     English, Spanish        6.6
# 19                                   English, Ukrainian        6.8
# 20                                              English        7.4
# 21                                              English        7.0
# 22                           English, French, Ukrainian        6.7
# 23                                              English        7.8
# 24                  English, Icelandic, Russian, French        6.1
# 25                                              English        7.2
# 26                                     English, Swedish        7.8
# 27     English, German, Xhosa, Russian, Romanian, Hindi        7.8
# 28                                    English, Japanese        5.8
# 29                                              English        7.0
# ...                                                 ...        ...
# 5013                                            English        6.8
# 5014                                            English        6.3
# 5015                                            English        7.1
# 5016                                            English        5.1
# 5017                                            English        3.3
# 5018                                            English        6.9
# 5019                                            English        4.6
# 5020                                            English        2.9
# 5021                                            English        6.6
# 5022                                   Swahili, English        7.5
# 5023                                            English        6.2
# 5024                                            English        4.0
# 5025                                            English        6.1
# 5026                         French, English, Cantonese        6.9
# 5027                                            Persian        7.5
# 5028                                            English        6.5
# 5029                                  Japanese, Spanish        7.4
# 5030                                            English        6.0
# 5031                                            English        5.3
# 5032                                            English        6.4
# 5033                                    English, French        6.9
# 5034                         English, Filipino, Tagalog        6.3
# 5035                                            Spanish        6.9
# 5036                                            English        7.6
# 5037                                            English        6.4
# 5038                                            English        7.7
# 5039                                            English        7.4
# 5040                                            English        6.2
# 5041                    English, Mandarin, Shanghainese        6.3
# 5042                                            English        6.5
#
# [5043 rows x 17 columns]

# %%
genres = ['Action', 'Adult', 'Adventure ', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Film Noir', 'Game-Show', 'History', 'Horror', 'Musical', 'Music', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']

# %%
for movie in df.iloc[:]:
    genres = df.iloc[i]['Genre'].split(', ')
    if genre
# Out:
# True

# %%
genres_total = []
for i in range(len(df)):
    movie_genres = df.iloc[i]['Genre'].split(', ')
    genres_total.extend(movie_genres)
    
Action = 0
Adult = 0
Adventure = 0 
Animation = 0
Biography = 0
Comedy = 0
Crime = 0
Documentary = 0
Drama = 0
Family = 0
Fantasy = 0
Film_Noir = 0
Game_Show = 0
History = 0
Horror = 0
Musical = 0
Music = 0
Mystery = 0
News = 0
Reality_TV = 0
Romance = 0
Sci_Fi = 0
Short = 0
Sport = 0
Talk_Show = 0
Thriller = 0
War = 0
Western = 0

for word in genres_total:
    if word == 'Action':
        Action += 1
    elif word == 'Adult':
        Adult += 1
    elif word == 'Adventure':
        Adventure += 1
    elif word == 'Animation':
        Animation += 1
    elif word == 'Biography':
        Biography += 1
    elif word == 'Comedy':
        Comedy += 1

    elif word == 'Crime':
        Crime += 1

    elif word == 'Documentary':
        Documentary += 1

    elif word == 'Drama':
        Drama += 1

    elif word == 'Family':
        Family += 1

    elif word == 'Fantasy':
        Fantasy += 1

    elif word == 'Film Noir':
        Film_Noir += 1

    elif word == 'Game-Show':
        Game_Show += 1

    elif word == 'History':
        History += 1

    elif word == 'Horror':
        Horror += 1

    elif word == 'Musical':
        Musical += 1

    elif word == 'Music':
        Music += 1

    elif word == 'Mystery':
        Mystery += 1

    elif word == 'News':
        News += 1

    elif word == 'Reality-TV':
        Reality_TV += 1

    elif word == 'Romance':
        Romance += 1

    elif word == 'Sci-Fi':
        Sci_Fi += 1

    elif word == 'Short':
        Short += 1

    elif word == 'Sport':
        Sport += 1

    elif word == 'Talk-Show':
        Talk_Show += 1

    elif word == 'Thriller':
        Thriller += 1

    elif word == 'War':
        War += 1

    else:
        Western += 1

# %%
Western # 101
War #206
Thriller #1406
Talk_Show #0
Sport #177
Short #7
Sci_Fi #621
Romance #1095
Reality_TV #2
News #3
Mystery #521
Music #212
Musical #132
Horror #584
History #224
Game_Show #1
Film_Noir #0
Fantasy #606
Family #544
Drama #2643
Documentary #120
Crime #909
Comedy #1893
Biography #312
Animation #242
Adventure #972
Adult #0
Action #1183
# Out:
# 1183

# %%
Musical + Music
DROP Film_Noir, GamE_Show, Adult, News, Reality_TV, Short, Talk_Show,
# Out:
# 0

# %%
li = []
for i in range(len(df)):
    movie_genres = df.iloc[i]['Genre'].split(', ')
    li.append(movie_genres)
    
final_genres = ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci_Fi', 'Sport', 'Thriller', 'War', 'Western']
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']

# %%
import numpy as np

for genre in final_genres:
    df[genre] = 0

for i in range(len(df)):
    movie_genres = df.iloc[i]['Genre'].split(', ')
    for genre in movie_genres:
        df.iloc[i][genre] = 1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py:915: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[key] = value

# %%
df
